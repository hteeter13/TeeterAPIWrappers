# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from pandas import json_normalize

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
string
# Out:
# 'clientid: 0c28ac5b85714331bc30ad43546a8651\nclientsecret: 8f4845a54a8146de8db70184babac495\nPlaylist variable/ID: 6fIBGTxbQBvx7QzN8YD23x'

# %%
string.split('\n')
# Out:
# ['clientid: 0c28ac5b85714331bc30ad43546a8651',
#  'clientsecret: 8f4845a54a8146de8db70184babac495',
#  'Playlist variable/ID: 6fIBGTxbQBvx7QzN8YD23x']

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
secrets_dict
# Out:
# {'clientid': '0c28ac5b85714331bc30ad43546a8651',
#  'clientsecret': '8f4845a54a8146de8db70184babac495',
#  'Playlist variable/ID': '6fIBGTxbQBvx7QzN8YD23x'}

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
audiolist1 = pd.read_csv('playlist1.csv')
audiolist1
# Out:
#                                            track.name  \
# 0                                Bimbo - Original Mix
# 1                               Do You Feel - Dub Mix
# 2      Toda La Noche - Offer Nissim and Asi Tal Remix
# 3      Toda La Noche - Offer Nissim and Asi Tal Remix
# 4      Toda La Noche - Offer Nissim and Asi Tal Remix
# 5   I Can Forgive (feat. Maya Simantov) - Sagi Kar...
# 6                                 Hands On - Club Mix
# 7                        Gracias a La Vida - Club Mix
# 8                        Gracias a La Vida - Club Mix
# 9                        Gracias a La Vida - Club Mix
# 10          Don't Stop the Dance - Reconstruction Mix
# 11                   Home - Offer Nissim Remix Part 2
# 12                 Perfect Love - Be My Boyfriend Mix
# 13                                   Miracle - Part B
# 14                                         I Feel You
# 15                                         I Feel You
# ...

# %%
audiolist2 = pd.read_csv('playlist2.csv')
audiolist2
# Out:
#                                             track.name             name  \
# 0                                 Stuck Inside A Cloud  George Harrison
# 1                                 Stuck Inside A Cloud  George Harrison
# 2                                 Stuck Inside A Cloud  George Harrison
# 3                                 Stuck Inside A Cloud  George Harrison
# 4                                         Now And Then      The Beatles
# ..                                                 ...              ...
# 123         All Things Must Pass - Anthology 3 Version      The Beatles
# 124                            Something - Studio Demo      The Beatles
# 125               Here Comes The Sun / The Inner Light      The Beatles
# 126  Isn't It A Pity - Session Outtakes And Jams / ...  George Harrison
# 127             Isn't It A Pity - Version 2 / 2020 Mix  George Harrison
#
#                    track.id  danceability  energy  key  loudness  speechiness  \
# ...

# %%
audiolist3 = pd.read_csv('playlist3.csv')
audiolist3
# Out:
#                track.name    name                track.id  danceability  \
# 0                 Debaser  Pixies  3FzKPS0oVknVlCW3PhxIHl         0.487
# 1              Bel Esprit  Pixies  3D65HtrWUQfB34buVYjgFH         0.457
# 2            Is She Weird  Pixies  3Ao3tTpiXLSmch1kTJZ7Fx         0.688
# 3                  Cactus  Pixies  2nqMzaaRiinfR2B4egiHgI         0.880
# 4           Break My Body  Pixies  5pVSOZVIWaRxF0zhjlnEUy         0.442
# 5         River Euphrates  Pixies  1FKWWmT46hgeerUUR7YedM         0.527
# 6       On Graveyard Hill  Pixies  2ce6x2fCzlgI2fnCAGJDUu         0.509
# 7   All I Think About Now  Pixies  07B4CFVNwG7oJ6pjQBt3am         0.251
# 8            Bone Machine  Pixies  58BsYHaWdK78SIZMWztmC3         0.632
# 9                 Caribou  Pixies  7noFstGWAG1n002hb6VKsY         0.322
# 10         La La Love You  Pixies  3vY7cKuKNY1oAsyVVn7AQz         0.702
# 11  Monkey Gone to Heaven  Pixies  1lFC3sMgOcDrVzNh8zXRnl         0.652
# ...

# %%
audiolist4 = pd.read_csv('playlist4.csv')
audiolist4
# Out:
#                       track.name              name                track.id  \
# 0    In the Name of Love (Pride)           JETFIRE  7FJXQOPTHobY0UCASddv0x
# 1    In the Name of Love (Pride)  Forever Tel Aviv  7FJXQOPTHobY0UCASddv0x
# 2    In the Name of Love (Pride)        Inbal Bibi  7FJXQOPTHobY0UCASddv0x
# 3                      Feel Free      Offer Nissim  0pqaWCejWat6c493baYoMu
# 4      One Min Before We All Die      Offer Nissim  5QqDh0d6ysVGMNXSXjYmIF
# ..                           ...               ...                     ...
# 255           Air - Original Mix     Maya Simantov  4MgnvWw4akE3G4e5KfhdjT
# 256           Air - Original Mix       Erick Ibiza  4MgnvWw4akE3G4e5KfhdjT
# 257           Air - Original Mix      Isak Salazar  4MgnvWw4akE3G4e5KfhdjT
# 258                 Show Me Love          MR.BLACK  5sJpuCRQmoWiyCwsdfdzGV
# 259                 Show Me Love      Offer Nissim  5sJpuCRQmoWiyCwsdfdzGV
#
# ...

# %%
audiolist5 = pd.read_csv('playlist5.csv')
audiolist5
# Out:
#                                            track.name              name  \
# 0                           Angel, Won't You Call Me?  The Decemberists
# 1                                               Shiny  The Decemberists
# 2                                           Oceanside  The Decemberists
# 3                                            Sunshine  The Decemberists
# 4   Everything I Try to Do, Nothing Seems to Turn ...  The Decemberists
# ..                                                ...               ...
# 59                                  I'll Be Your Girl  The Decemberists
# 60                                    Sucker's Prayer  The Decemberists
# 61                                     Tripping Along  The Decemberists
# 62                                Down On The Knuckle  The Decemberists
# 63                                     Midlist Author  The Decemberists
#
#                   track.id  danceability  energy  key  loudness  speechiness  \
# ...

# %%
audiolist6 = pd.read_csv('playlist6.csv')
audiolist6
# Out:
#                             track.name  name                track.id  \
# 0                         The Distance  CAKE  1szwDbVdIdoQq5mG5GXAmJ
# 1            Short Skirt / Long Jacket  CAKE  3OOFEF20WqtsUPcRbPY3L7
# 2                          Never There  CAKE  7aKWgpecgLEqisWcXPElDl
# 3                             War Pigs  CAKE  5Cg6S5BXG6lXqjijSK9zFh
# 4                       I Will Survive  CAKE  4THrHKyBL0yaDDw9yg37Zk
# 5                       Love You Madly  CAKE  5jhfa76FhqtD3Boij6MAKS
# 6                            Let Me Go  CAKE  0qdJUhXtk9u7sdSwfBB5XU
# 7                               Wheels  CAKE  0Wm1TSXJ3vH4Hh7qxW0ihY
# 8            Perhaps, Perhaps, Perhaps  CAKE  0EzT2QizrC4PqT0iQilP1A
# 9                        Comfort Eagle  CAKE  2qQCU22yQXKjhytKUBxa59
# 10                  Sheep Go To Heaven  CAKE  4G8Eu3EDQZYhHPfJMFCv8V
# 11             Rock 'n' Roll Lifestyle  CAKE  4tRkMAL93DFmaMDUHOHuBH
# 12                       Frank Sinatra  CAKE  4KF92hpwTpYBC8rdfKd7Po
# ...

# %%
audiolist7 = pd.read_csv('playlist7.csv')
audiolist7
# Out:
#                                            track.name              name  \
# 0                                        On The Radio      Donna Summer
# 1                               Love To Love You Baby      Donna Summer
# 2                Try Me, I Know We Can Make It - Edit      Donna Summer
# 3                                         I Feel Love      Donna Summer
# 4                                            Our Love      Donna Summer
# 5                                I Remember Yesterday      Donna Summer
# 6                         I Love You - Single Version      Donna Summer
# 7                                        Heaven Knows      Donna Summer
# 8                                          Last Dance      Donna Summer
# 9                     MacArthur Park - Single Version      Donna Summer
# 10                    MacArthur Park - Single Version      Donna Summer
# 11                    MacArthur Park - Single Version      Donna Summer
# ...

# %%
audiolist8 = pd.read_csv('playlist8.csv')
audiolist8
# Out:
#                                              track.name             name  \
# 0                                     It's A Love Thing  Various Artists
# 1              He's the Greatest Dancer - 1995 Remaster  Various Artists
# 2                                               Outside   George Michael
# 3                                 Little L - Remastered       Jamiroquai
# 4                             Let It Whip (Re-Recorded)  Various Artists
# ...                                                 ...              ...
# 1506                    Knock Me Out - Original Version      Gary's Gang
# 1507                                            Push Up      Freestylers
# 1508                                         Lovin' You  Minnie Riperton
# 1509  She's A Bad Mama Jama (She's Built, She's Stac...     Carl Carlton
# 1510                              In De Disco - 12" Mix         Noodweer
#
#                     track.id  danceability  energy  key  loudness  \
# ...

# %%
audiolist9 = pd.read_csv('playlist9.csv')
audiolist9
# Out:
#                track.name                     name                track.id  \
# 0                Santeria                  Sublime  2hnMS47jN0etwvFPzYk11f
# 1      Livin' On A Prayer                 Bon Jovi  37ZJ0p5Jm13JPevGcx4SkF
# 2     Sweet Child O' Mine            Guns N' Roses  7snQQk1zcKl8gZ92AnueZW
# 3              What I Got                  Sublime  3B4q6KbHbGV51HO3GznBFF
# 4      Kickstart My Heart              Mötley Crüe  7GonnnalI2s19OCQO1J7Tf
# ...                   ...                      ...                     ...
# 998     Too Fast For Love              Mötley Crüe  4PDNOmMej8sc1mkiZfvW9w
# 999             Jailhouse                  Sublime  01ZoBkMJAxjPx5gQcNR7Yl
# 1000             Shake Me               Cinderella  1Qjpl8Kav6rrO92ZuG0OK8
# 1001            This Love                  Pantera  0Yfpc5zHc9pElVCQ1bPlF4
# 1002        Dot Your Eyes  Five Finger Death Punch  7zyJ2g9o0nVOBbDavVveCl
#
# ...

# %%
audiolist10 = pd.read_csv('playlist10.csv')
audiolist10
# Out:
#                                              track.name             name  \
# 0                   Bohemian Rhapsody - Remastered 2011            Queen
# 1                                   Sweet Child O' Mine    Guns N' Roses
# 2                               Smells Like Teen Spirit          Nirvana
# 3                             Imagine - Remastered 2010      John Lennon
# 4                                      You're the Voice     John Farnham
# ...                                                 ...              ...
# 1014                                   Running on Empty   Jackson Browne
# 1015  Every Little Thing She Does Is Magic - Remaste...       The Police
# 1016                               Doo Wop (That Thing)  Ms. Lauryn Hill
# 1017                          The Boys Are Back In Town       Thin Lizzy
# 1018                                             Desire               U2
#
#                     track.id  danceability  energy  key  loudness  \
# ...

# %%
audiolist11 = pd.read_csv('playlist11.csv')
audiolist11
# Out:
#                                         track.name                name  \
# 0              Bohemian Rhapsody - Remastered 2011               Queen
# 1                 Hotel California - 2013 Remaster              Eagles
# 2                                      Billie Jean     Michael Jackson
# 3                      Let It Be - Remastered 2009         The Beatles
# 4     (I Can't Get No) Satisfaction - Mono Version  The Rolling Stones
# ...                                            ...                 ...
# 6075                       Young Guns (Go for It!)               Wham!
# 6076                                        Gloria      Laura Branigan
# 6077                                  House Of Fun             Madness
# 6078                              Mama Used To Say              Junior
# 6079                              Just an Illusion         Imagination
#
#                     track.id  danceability  energy  key  loudness  \
# ...

# %%
audiolist12 = pd.read_csv('playlist12.csv')
audiolist12
# Out:
#                                           track.name               name  \
# 0                                          The Color       Doc Robinson
# 1                                          The Color      The Kickdrums
# 2                                          Slip Away       Doc Robinson
# 3   Leave a Light on (Acoustic) [feat. Taylor Meier]       Doc Robinson
# 4                                Take Me by the Hand       Doc Robinson
# 5                                        Golden Daze       Doc Robinson
# 6                                         Drive Slow       Doc Robinson
# 7                                      Ride the Wave       Doc Robinson
# 8                                      Ride the Wave      The Kickdrums
# 9                             If You're Gonna Ignite       Doc Robinson
# 10                                           Mt Hood       Doc Robinson
# 11                                     Break My Fall       Doc Robinson
# ...

# %%
audiolist13 = pd.read_csv('playlist13.csv')
audiolist13
# Out:
#               track.name              name                track.id  \
# 0            Te Felicito           Shakira  2rurDawMfoKP4uHyb2kJBt
# 1            Te Felicito    Rauw Alejandro  2rurDawMfoKP4uHyb2kJBt
# 2         Imposible Amor     NATTI NATASHA  5oMrqQUkuLMg4DvlCEZfXx
# 3         Imposible Amor            Maluma  5oMrqQUkuLMg4DvlCEZfXx
# 4                PENDEJO  Enrique Iglesias  5cy2dREJqJAyf3CNr509W7
# ..                   ...               ...                     ...
# 470  Si Quieren Frontear           Quevedo  6bQ5823aHmFVKLZW8E7rRo
# 471             RUMBATÓN      Daddy Yankee  3XjN0mvFkQp1FMVM9Ro5hm
# 472      I'm Good (Blue)      David Guetta  4uUG5RXrOk84mYEfFvj3cK
# 473      I'm Good (Blue)        Bebe Rexha  4uUG5RXrOk84mYEfFvj3cK
# 474          Say My Name      David Guetta  0YammaEkYSeo9vQYZ1OwS6
#
#      danceability  energy  key  loudness  speechiness  acousticness  \
# 0           0.695   0.636    5    -4.654       0.3170       0.23400
# ...

# %%
audioframe = pd.concat([audiolist1,audiolist2,audiolist3,audiolist4,audiolist5,audiolist6,audiolist7,audiolist8,audiolist9,audiolist10,audiolist11,audiolist12,audiolist13], axis=0)
audioframe
# Out:
#                                          track.name             name  \
# 0                              Bimbo - Original Mix     Offer Nissim
# 1                             Do You Feel - Dub Mix     Offer Nissim
# 2    Toda La Noche - Offer Nissim and Asi Tal Remix     Offer Nissim
# 3    Toda La Noche - Offer Nissim and Asi Tal Remix  Meital De Razon
# 4    Toda La Noche - Offer Nissim and Asi Tal Remix          Asi Tal
# ..                                              ...              ...
# 470                             Si Quieren Frontear          Quevedo
# 471                                        RUMBATÓN     Daddy Yankee
# 472                                 I'm Good (Blue)     David Guetta
# 473                                 I'm Good (Blue)       Bebe Rexha
# 474                                     Say My Name     David Guetta
#
#                    track.id  danceability  energy  key  loudness  speechiness  \
# ...
